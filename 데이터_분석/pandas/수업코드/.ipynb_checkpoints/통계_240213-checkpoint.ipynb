# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

plt.rcParams['figure.figsize']=(6,4)  # figure 사이즈 변경
plt.rcParams['scatter.marker']='*'

#한글 폰트 적용하기/ 보통  맑은 고딕체 사용
from matplotlib import font_manager, rc
font = 'C:/Windows/Fonts/Malgun.ttf'
font_name = font_manager.FontProperties(fname=font).get_name()
rc('font', family=font_name)

# %%
ebola=pd.read_csv('./data/country_timeseries.csv', parse_dates=['Date'])
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
#  15  Deaths_UnitedStates  18 non-null     float64
#  16  Deaths_Spain         16 non-null     float64
#  17  Deaths_Mali          12 non-null     float64
# dtypes: datetime64[ns](1), float64(16), int64(1)
# memory usage: 17.3 KB

# %%
plt.plot(ebola['Date'],ebola['Cases_Guinea'])

# %%
ebola['Date_quarter'] = ebola['Date'].dt.quarter
plt.plot(ebola['Date_quarter'],ebola['Cases_Guinea'])

# %%
ebola['Date_quarter']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      4
#       ..
# 117    1
# 118    1
# 119    1
# 120    1
# 121    1
# Name: Date_quarter, Length: 122, dtype: int32

# %%
ebola['Date_year'] = ebola['Date'].dt.year

# %%
ebola_quarter=ebola.groupby(['Date_year','Date_quarter'])['Cases_Guinea'].mean()

# %%
ebola_quarter.plot()
# Out:
# <Axes: xlabel='Date_year,Date_quarter'>

# %%
pd.date_range('2014-01-15', '2014-03-30', freq='M')
# Out:
# DatetimeIndex(['2014-01-31', '2014-02-28'], dtype='datetime64[ns]', freq='M')

# %%
ebola_month=ebola.set_index('Date').resample('Q').mean()

# %%
plt.plot(ebola_month.index, ebola_month['Cases_Guinea'])

# %%
plt.plot(ebola.Date, ebola['Cases_Guinea'])
plt.xticks(pd.date_range('2014-03-22','2015-01-02', freq='Q', labels=['2014-1q','2014-2q','2014-3q','2014-4q' ]))
plt.xticks(rotation=45)

# %%
plt.plot(ebola['Date'],ebola['Cases_Guinea'])
plt.xlim(pd.Timestamp('2014-12-30'),pd.Timestamp('2015-01-05'))
plt.ylim(2700,2800)
plt.xticks(pd.date_range('2014-12-31', '2015-01-04', freq='2D'))
# Out:
# ([<matplotlib.axis.XTick at 0x19621bac650>,
#   <matplotlib.axis.XTick at 0x19622015350>,
#   <matplotlib.axis.XTick at 0x19622001b50>],
#  [Text(16435.0, 0, '2014-12-31'),
#   Text(16437.0, 0, '2015-01-02'),
#   Text(16439.0, 0, '2015-01-04')])

# %%
pd.Timestamp('2014-12-30')
# Out:
# Timestamp('2014-12-30 00:00:00')

# %%
## 데이터수집 11.12

# %%
import requests

dfs=[]
for page in range(1,21):
    url = f'https://m.stock.naver.com/api/stock/005930/price?pageSize=20&page={page}'
    response = requests.get(url)
    df=pd.DataFrame(response.json()) 
    dfs.append(df)
samsung=pd.concat(dfs)
response
# Out:
# <Response [200]>

# %%
pd.DataFrame(response.json())  # json 파일을 데이터프레임으로
# Out:
#    localTradedAt closePrice compareToPreviousClosePrice  \
# 0     2024-02-13     74,800                         700
# 1     2024-02-08     74,100                        -900
# 2     2024-02-07     75,000                         600
# 3     2024-02-06     74,400                         100
# 4     2024-02-05     74,300                        -900
# 5     2024-02-02     75,200                       1,600
# 6     2024-02-01     73,600                         900
# 7     2024-01-31     72,700                      -1,600
# 8     2024-01-30     74,300                        -100
# 9     2024-01-29     74,400                       1,000
# 10    2024-01-26     73,400                        -700
# 11    2024-01-25     74,100                         100
# 12    2024-01-24     74,000                      -1,200
# 13    2024-01-23     75,200                         100
# 14    2024-01-22     75,100                         400
# 15    2024-01-19     74,700                       3,000
# 16    2024-01-18     71,700                         700
# 17    2024-01-17     71,000                      -1,600
# 18    2024-01-16     72,600                      -1,300
# 19    2024-01-15     73,900                         800
#
#                             compareToPreviousPrice fluctuationsRatio  \
# 0    {'code': '2', 'text': '상승', 'name': 'RISING'}              0.94
# 1   {'code': '5', 'text': '하락', 'name': 'FALLING'}             -1.20
# 2    {'code': '2', 'text': '상승', 'name': 'RISING'}              0.81
# 3    {'code': '2', 'text': '상승', 'name': 'RISING'}              0.13
# 4   {'code': '5', 'text': '하락', 'name': 'FALLING'}             -1.20
# 5    {'code': '2', 'text': '상승', 'name': 'RISING'}              2.17
# 6    {'code': '2', 'text': '상승', 'name': 'RISING'}              1.24
# 7   {'code': '5', 'text': '하락', 'name': 'FALLING'}             -2.15
# 8   {'code': '5', 'text': '하락', 'name': 'FALLING'}             -0.13
# 9    {'code': '2', 'text': '상승', 'name': 'RISING'}              1.36
# 10  {'code': '5', 'text': '하락', 'name': 'FALLING'}             -0.94
# 11   {'code': '2', 'text': '상승', 'name': 'RISING'}              0.14
# 12  {'code': '5', 'text': '하락', 'name': 'FALLING'}             -1.60
# 13   {'code': '2', 'text': '상승', 'name': 'RISING'}              0.13
# 14   {'code': '2', 'text': '상승', 'name': 'RISING'}              0.54
# 15   {'code': '2', 'text': '상승', 'name': 'RISING'}              4.18
# 16   {'code': '2', 'text': '상승', 'name': 'RISING'}              0.99
# 17  {'code': '5', 'text': '하락', 'name': 'FALLING'}             -2.20
# 18  {'code': '5', 'text': '하락', 'name': 'FALLING'}             -1.76
# 19   {'code': '2', 'text': '상승', 'name': 'RISING'}              1.09
#
#    openPrice highPrice lowPrice  accumulatedTradingVolume
# 0     74,800    75,200   74,400                  12390458
# 1     75,000    75,200   73,600                  20810708
# 2     74,600    75,500   74,300                  16566445
# 3     74,300    74,700   73,300                  14559254
# 4     74,200    74,800   73,500                  19026021
# 5     74,000    75,200   73,700                  14955881
# 6     73,000    74,200   72,900                  19881033
# 7     73,400    74,000   72,500                  15703560
# 8     75,000    75,300   73,700                  12244418
# 9     73,800    75,200   73,500                  13976521
# 10    73,700    74,500   73,300                  11160062
# 11    74,200    74,800   73,700                  11737747
# 12    75,200    75,200   73,500                  12860661
# 13    75,700    75,800   74,300                  14786224
# 14    75,900    76,000   75,000                  19673375
# 15    73,500    74,700   73,000                  23363427
# 16    71,600    72,000   70,700                  17853397
# 17    73,100    73,300   71,000                  22683660
# 18    73,500    73,700   72,500                  14760415
# 19    73,200    74,000   73,200                  13212339

# %%
samsung['Date']=pd.to_datetime(samsung['localTradedAt'])

# %%
sns.lineplot(data=samsung, x='Date', y='closePrice' )
# Out:
# <Axes: xlabel='Date', ylabel='closePrice'>

# %%
samsung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   localTradedAt                400 non-null    object
#  1   closePrice                   400 non-null    object
#  2   compareToPreviousClosePrice  400 non-null    object
#  3   compareToPreviousPrice       400 non-null    object
#  4   fluctuationsRatio            400 non-null    object
#  5   openPrice                    400 non-null    object
#  6   highPrice                    400 non-null    object
#  7   lowPrice                     400 non-null    object
#  8   accumulatedTradingVolume     400 non-null    int64
#  9   Date                         400 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 34.4+ KB

# %%
samsung['closePrice']=samsung['closePrice'].str.replace(',','').astype(int)

# %%
sns.lineplot(data=samsung, x='Date', y='closePrice' )
# Out:
# <Axes: xlabel='Date', ylabel='closePrice'>

# %%
sam=samsung[['Date','closePrice']].set_index('Date')
sam
# Out:
#             closePrice
# Date
# 2024-02-13       74700
# 2024-02-08       74100
# 2024-02-07       75000
# 2024-02-06       74400
# 2024-02-05       74300
# ...                ...
# 2022-07-06       56400
# 2022-07-05       57200
# 2022-07-04       57100
# 2022-07-01       56200
# 2022-06-30       57000
#
# [400 rows x 1 columns]

# %%
sam_week=sam.resample('W-SUN').mean()

# %%
sns.lineplot(sam_week)
# Out:
# <Axes: xlabel='Date'>

# %%
sam_mon=sam.resample('MS').mean()
sns.lineplot(sam_mon)
# Out:
# <Axes: xlabel='Date'>

# %%
sns.lineplot(data=sam )
sns.lineplot(data=sam_mon)
sns.lineplot(data=sam_week)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.plot(sam)
plt.plot(sam_week)
plt.plot(sam_mon)

# %%
# 시계열 데이터 분석시 resample,range외에  
# 단순지수평활법/이동평균법 으로도 그래프를 부드럽게/ 러신머닝
# shift, diff() 함수들을 사용

# %%
# 전과 비교하여 증감 알려고 할때 
sam['closePrice']
# Out:
# Date
# 2024-02-13    74700
# 2024-02-08    74100
# 2024-02-07    75000
# 2024-02-06    74400
# 2024-02-05    74300
#               ...
# 2022-07-06    56400
# 2022-07-05    57200
# 2022-07-04    57100
# 2022-07-01    56200
# 2022-06-30    57000
# Name: closePrice, Length: 400, dtype: int32

# %%
# 방법1 안빠른 방법 shift
sam['tomorrow']=sam['closePrice'].shift()
sam['yesterday']=sam['closePrice'].shift(-1)
sam.head()
# Out:
#             closePrice  tomorrow  yesterday
# Date
# 2024-02-13       74700       NaN    74100.0
# 2024-02-08       74100   74700.0    75000.0
# 2024-02-07       75000   74100.0    74400.0
# 2024-02-06       74400   75000.0    74300.0
# 2024-02-05       74300   74400.0    75200.0

# %%
sam['diff']=sam['closePrice']-sam['yesterday']
sam.head()
# Out:
#             closePrice  tomorrow  yesterday   diff
# Date
# 2024-02-13       74700       NaN    74100.0  600.0
# 2024-02-08       74100   74700.0    75000.0 -900.0
# 2024-02-07       75000   74100.0    74400.0  600.0
# 2024-02-06       74400   75000.0    74300.0  100.0
# 2024-02-05       74300   74400.0    75200.0 -900.0

# %%
# 방식2 빠른 방법 diff
sam['diff2']=sam.closePrice.diff(-1)

# %%
plt.plot(sam['diff'])   # 차분: 전날과의 차이만, 증감의 특성을 알기위해)
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\admin\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
