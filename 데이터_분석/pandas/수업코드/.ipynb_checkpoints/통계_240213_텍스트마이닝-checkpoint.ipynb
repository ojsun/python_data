# %% [markdown]
# #### 비정형데이터 - 텍스트마이닝

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

plt.rcParams['figure.figsize']=(6,4)  # figure 사이즈 변경

warnings.filterwarnings('ignore')
sns.set_palette('Paired')

#한글 폰트 적용하기/ 보통  맑은 고딕체 사용
from matplotlib import font_manager, rc
font = 'C:/Windows/Fonts/Malgun.ttf'
font_name = font_manager.FontProperties(fname=font).get_name()
rc('font', family=font_name)

# %%
import FinanceDataReader as fdr

# %%
import requests
from bs4 import BeautifulSoup

# %%
fdr.DataReader('005930', start='2023-01-06')
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2023-01-06  58300  59400  57900  59000  17334989  0.013746
# 2023-01-09  59700  60700  59600  60700  18640107  0.028814
# 2023-01-10  60200  61100  59900  60400  14859797 -0.004942
# 2023-01-11  61000  61200  60300  60500  12310751  0.001656
# 2023-01-12  61100  61200  59900  60500  16102561  0.000000
# ...           ...    ...    ...    ...       ...       ...
# 2024-02-05  74200  74800  73500  74300  19026021 -0.011968
# 2024-02-06  74300  74700  73300  74400  14559254  0.001346
# 2024-02-07  74600  75500  74300  75000  16566445  0.008065
# 2024-02-08  75000  75200  73600  74100  20810708 -0.012000
# 2024-02-13  74800  75200  74400  75200  20508475  0.014845
#
# [270 rows x 6 columns]

# %%
url = 'https://www.gmarket.co.kr/n/best'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')
images = soup.select('img.image__lazy')
codes = []
for image in images:
    code = image.get('src').split('/')[3]
    codes.append(code)
print(codes)
# Out:
# ['2036523446', '2771188810', '2832938734', '3433508332', '1234252346', '2179432000', '3039555146', '3501632122', '1862824465', '1519672189', '3498395902', '2412883938', '2476792485', '1372178412', '3448367286', '3084408612', '2722121500', '3433708140', '3506406398', '3475738722', '2455619393', '2832851792', '1778069304', '3506352811', '1430266775', '3355966461', '3243852132', '3384041576', '1874252366', '1926098538', '3448087601', '3523721424', '1635837414', '161267854', '2798877007', '3060068006', '3519545761', '3401457015', '1776265578', '2315162136', '2767152704', '3317370357', '2098489802', '2799604339', '1655242371', '3519545810', '3475148479', '3132577817', '1655242060', '2328254013', '2150845686', '2398454884', '1910040585', '667938939', '1744541512', '1589098023', '1920684660', '1655241628', '2218320186', '1920642031', '3394720069', '3277033708', '3153495682', '3520658533', '1651273917', '925716760', '3020161230', '3448066766', '2866359272', '1649311897', '2010228954', '237872783', '2899878671', '2832808901', '3133155923', '1101182286', '2260661525', '220228006', '1350339365', '3499123329', '3374032553', '3471973464', '3181693148', '1232338881', '3084413100', '3150456880', '1119049865', '2686928110', '1655243018', '1899274105', '2386522093', '2753779947', '2468855226', '3383368133', '3509224160', '2119505327', '1791763241', '1668094482', '2522267922', '2317863111', '2246502676', '2429087685', '2433792583', '3273189236', '2858031232', '2250306667', '3440620555', '822806498', '2686996033', '3433711635', '2826727330', '3448085273', '2104251373', '484828506', '1510637585', '1153420307', '1577510972', '1638941681', '3389030502', '2621357304', '576442682', '2540476673', '2434572793', '3519318827', '3138397116', '3283586105', '1284344651', '3211814463', '3080554600', '2611508735', '1727333769', '2183617402', '2305559120', '175173782', '2881809320', '447292392', '972418391', '3198665863', '2740583029', '3018178115', '2754051293', '3519648573', '1913602226', '3463535831', '1817538454', '3424161402', '2412883387', '1174602556', '3499090133', '2584905546', '1654805524', '1124083462', '3466726363', '776582823', '3213759767', '2301626527', '3488744751', '1554561741', '2846290240', '2316903829', '2024286638', '2767677609', '2316892877', '1654699774', '2809510617', '166590202', '1722509217', '3229806025', '3433606002', '2090527116', '221218898', '1737528085', '3125232466', '2547597591', '2945459487', '3509771306', '214340838', '3179219373', '2061950099', '1990389220', '1579104167', '3245115781', '3244061569', '1913600243', '2916675878', '2252219580', '3106997707', '2568237082', '3456060073', '1470422337', '3421611349', '2995524544', '2386555516', '3006758113', '3184099031', '1817970537', '2186417742', '3150894622', '3287753748', '2304499072']

# %%
# 지마켓 리뷰 크롤링
all_reviews = []
for code in codes[:5]:
    url = 'http://item.gmarket.co.kr/Review/Premium'
    for page in range(1,201):
        break_point = 0
        params = {'goodsCode': code,
                'pageNo': page,
                'sort': 0,
                'totalPage': 0 }
        
        response = requests.post(url, params)

        if response.status_code == 200:
            # 크롤링(총 리뷰의 수)
            review = BeautifulSoup(response.content, 'html.parser')
            rows = review.select('table > tbody tr')
            for row in rows:
                try:
                    content = row.select_one('td p:nth-child(3)').text.strip()
                    all_reviews.append({'code':code, 'content':content})
                except:
                    break_point = 1
                    break

            if break_point == 1:
                break
        else:
            continue

# %%
# 데이터프레임으로 변환
pd.DataFrame(all_reviews)
# Out:
#            code                                   content
# 0    2036523446                      ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ 감사합니다
# 1    2036523446                             잘 보겠습니다 감사합니다
# 2    2036523446                             잘 보겠습니다 감사합니다
# 3    2036523446                             잘 보겠습니다 감사합니다
# 4    2036523446                             잘 보겠습니다 감사합니다
# ..          ...                                       ...
# 365  1234252346                         배송빨라요 맘에들어요 이것믄써요
# 366  1234252346                   제품 포장상태양호 \n좋은제품잘.사용할게요
# 367  1234252346  인덕션 세제 이것저것 써봤는데 갠적으로 이제품이 좋아요.\n깨끗이 닦여요
# 368  1234252346                          향기도좋고 깨끗하게 잘지워져요
# 369  1234252346                               안 써봤는데 조을케요
#
# [370 rows x 2 columns]

# %%
# 워드클라우드
# !pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

with open('../data/소나기.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
font = 'C:/Windows/Fonts/Malgun.ttf'

# %%
wc = WordCloud(font_path=font).generate(text)   # 워드크라우드는 따로 한글 설정해주어야 함

# %%
plt.imshow(wc)
plt.axis('off')

# %%
# 마스크
from PIL import Image

# %%
mask= np.array(Image.open('../data/alice_mask.png'))  
# 0인 검은부분에 워드클라우드 뿌림
wc = WordCloud(font_path=font, mask=mask, background_color='#ffffff', colormap='Blues').generate(text)

# %%
plt.imshow(wc)
plt.axis('off')

# %%
# 다른 이미지인 경우(예: 3채널)에는 변환작업해야
mask= np.array(Image.open('이미지경로'))   # 보완

# %%
# KoNLPy 자연어 처리
# !pip install konlpy

# %%
from konlpy.tag import Okt, Hannanum, Kkma, Komoran
okt = Okt()    # Twitter -앞으로 사용
han=Hannanum()
kkma=Kkma()
komoran=Komoran()

word=okt.morphs(text)   # 동사 포함
word2=han.morphs(text)  # 명사
word3=kkma.nouns(text)    # 모든 형태소 
word4=komoran.pos(text)  #

# %%
print(word[:10])
print(word2[:10])
print(word3[:10])
print(word4[:10])
# Out:
# ['않다', '\n', '되어다', '\n', '되다', '\n', '하다', '\n', '어떻다', '\n']
# ['않', '다', '되', '이', '어다', '되', '이', '다', '하', '다']
# ['하다', '이', '휴', '우리', '저희', '의해', '을', '를', '의', '으']
# [('않', 'VX'), ('다', 'EC'), ('되', 'VV'), ('어다', 'EC'), ('되', 'VV'), ('다', 'EC'), ('하', 'VV'), ('다', 'EC'), ('어떻', 'VA'), ('다', 'EC')]

# %%
from collections import Counter
words=Counter(word) # 형태소별 갯수 세기: 내림차순
words=dict(Counter(word3))

# %%
font = 'C:/Windows/Fonts/Malgun.ttf'
wc = WordCloud(font_path=font, background_color='#ffffff').generate_from_frequencies(words)
plt.imshow(wc)

# %%
# 불용어 사전
with open('../data/stopword.txt', 'r', encoding='utf-8') as f:
    stopword = f.read()
stopwords=stopword.split("\n")
print(stopwords)

# %%
fillter_word=[]
for word in word2:
    if word not in stopwords:
        fillter_word.append(word)
words=dict(Counter(word3))
words

# %%
wc = WordCloud(font_path=font, background_color='#ffffff', stopwords=set(stopwords)).generate_from_frequencies(words)
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
df=pd.DataFrame(all_reviews)
df.head()
# Out:
#          code               content
# 0  2036523446  ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ 감사합니다
# 1  2036523446         잘 보겠습니다 감사합니다
# 2  2036523446         잘 보겠습니다 감사합니다
# 3  2036523446         잘 보겠습니다 감사합니다
# 4  2036523446         잘 보겠습니다 감사합니다

# %%
# 중복제거
df=df.drop_duplicates('content')
df.head()
# Out:
#          code               content
# 0  2036523446  ㅋㅋㅋㅋ ㅋㅋㅋㅋ ㅋㅋㅋㅋ 감사합니다
# 1  2036523446         잘 보겠습니다 감사합니다
# 7  2036523446         노래 재밋어욯ㅎㅎ불러줘요
# 8  2036523446        동물소리만 요고는 별루,.
# 9  2036523446      악숙한 송 가득 넘 젛아요ㅛㅛ

# %%
# 특정 물품에대한 리뷰데이터만 하나의 문자열로 들고오기
def select_item():
    df2=df[df['code'] == item_id]
    return ' '.join(df['content'].values)

# %%
# 형태소분석
def tokenize(text):
    kkma=Kkma()
    word=kkma.morphs(text)
    return word

# %%
# 불용어 처리 + counter  작업
def stop_count(word):
    fillter_word=[]
    for word in word2:
        if word not in stopwords:
            fillter_word.append(w)
    words=dict(Counter(word3))
    return words

# %%
item_id
text=select_item(item_id)
word=tokenize(text)
words=stop_count(word)
word_cloud(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 text=select_item(item_id)
#       2 word=tokenize(text)
#       3 words=stop_count(word)
#
# NameError: name 'item_id' is not defined
