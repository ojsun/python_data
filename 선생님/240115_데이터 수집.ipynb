# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardList.do?bbsId=BBSMSTR_000000000008'

response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
table = soup.select_one('table > tbody')
rows = table.select('tr')
# rows = soup.select('table > tbody > tr')

# %%
<tr>
 <td class="res_hide">15279</td>
 <td class="l"><div class="wrap"><a href="/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&amp;nttId=106441" onclick="javascript:fn_egov_inqire_notice('106441', 'BBSMSTR_000000000008'); return false;">1월 가뭄 예‧경보 발표 </a></div></td>
 <td class="res_hide"><img alt="첨부파일" src="/images/board/icon_file.gif;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20"></img></td>
 <td class="res_hide">기후재난대응과</td>
 <td>2024.01.15.</td>
 <td class="res_hide">42</td>
</tr>

# %%
datas = []
for row in rows:
    num = row.select_one('td:nth-child(1)').text.strip()
    title = row.select_one('td:nth-child(2)').text.strip()
    author = row.select_one('td:nth-child(4)').text.strip()
    date = row.select_one('td:nth-child(5)').text.strip()
    url = 'https://www.mois.go.kr' + row.select_one('a').get('href')
    datas.append( [num, title, author, date, url] )

# %%
print(datas)
# Out:
# [['15279', '1월 가뭄 예‧경보 발표', '기후재난대응과', '2024.01.15.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106441'], ['15278', '전북특별자치도 데이터 전환, 필요한 민원서류는 미리 챙겨주세요', '자치분권제도과', '2024.01.15.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106440'], ['15277', '연말정산용 증명서, 정부24에서 간편하게 발급하세요', '정부포털운영팀', '2024.01.15.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106439'], ['15276', '겨울철 취약계층 한파 및 화재 대비 현장점검 실시', '재난대응총괄과', '2024.01.13.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106438'], ['15275', '어린이 통학로 안전 확보를 위한 현장점검 실시', '안전개선과', '2024.01.12.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106427'], ['15274', '주민 보호를 위한 민방위 시설 관리에 만전', '위기관리지원과', '2024.01.12.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106403'], ['15273', '경기 화성 지역 수질오염물질 확산 방지에 총력', '환경재난대응과', '2024.01.12.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106429'], ['15272', '몰라서 못 받던 혜택, 정부가 알아서 챙겨준다', '공공지능정책과', '2024.01.11.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106366'], ['15271', '누구나 더 쉽게 이해하고 사용할 수 있도록 공공 웹‧앱 본격 개선', '공공서비스혁신과', '2024.01.11.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106365'], ['15270', '제22대 총선 대비 「공명선거지원상황실」 본격 운영', '선거의회자치법규과', '2024.01.11.', 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardArticle.do;jsessionid=WV9sMobyMIBpxYm0qxAIbMJT.node20?bbsId=BBSMSTR_000000000008&nttId=106357']]

# %%
import json
url = 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardList.do?bbsId=BBSMSTR_000000000008'
params = {
    'pageIndex' : 1529
}
response = requests.post(url, data = params)
print(response)
# Out:
# <Response [200]>

# %%
rows
# Out:
# [<tr>
#  <td colspan="6">
#  								자료가 없습니다. 다른 검색조건을 선택해주세요
#  							</td>
#  </tr>]

# %%
soup = BeautifulSoup(response.content, 'html.parser')
table = soup.select_one('table > tbody')
rows = table.select('tr')
datas = []
for row in rows:
    num = row.select_one('td:nth-child(1)').text.strip()
    title = row.select_one('td:nth-child(2)').text.strip()
    author = row.select_one('td:nth-child(4)').text.strip()
    date = row.select_one('td:nth-child(5)').text.strip()
    url = 'https://www.mois.go.kr' + row.select_one('a').get('href')
    datas.append( [num, title, author, date, url] )
    break
print(datas[0])
# Out:
# -----------------------------------------------------------------
# AttributeError                  Traceback (most recent call last)
# Cell In[36], line 7
#       5 for row in rows:
#       6     num = row.select_one('td:nth-child(1)').text.strip()
# ----> 7     title = row.select_one('td:nth-child(2)').text.strip()
#       8     author = row.select_one('td:nth-child(4)').text.strip()
#       9     date = row.select_one('td:nth-child(5)').text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
datas = []
for page in range(1528, 1531): # 1 ~ 10 
    print(page)
    break_point = 0
    url = 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardList.do?bbsId=BBSMSTR_000000000008'
    params = {
        'pageIndex' : page
    }
    response = requests.post(url, data = params)
    
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.select_one('table > tbody')
    rows = table.select('tr')
    for row in rows:
        num = row.select_one('td:nth-child(1)').text.strip()
        try:
            title = row.select_one('td:nth-child(2)').text.strip()
        except:
            break_point = 1
            break
        author = row.select_one('td:nth-child(4)').text.strip()
        date = row.select_one('td:nth-child(5)').text.strip()
        url = 'https://www.mois.go.kr' + row.select_one('a').get('href')
        datas.append( [num, title, author, date, url] )
        
    if break_point == 1:
        break
# Out:
# 1528
# 1529

# %%
datas = []
for page in range(1527, 1531): # 1 ~ 10 
    print(page)
    url = 'https://www.mois.go.kr/frt/bbs/type010/commonSelectBoardList.do?bbsId=BBSMSTR_000000000008'
    params = {
        'pageIndex' : page
    }
    response = requests.post(url, data = params)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # 테이블의 페이지 수를 크롤링
    page_num = soup.select_one('span.doc_totle').text.strip()
    page_num = page_num.split('/')[-1]
    
    # 테이블에 있는 데이터를 크롤링
    
    table = soup.select_one('table > tbody')
    rows = table.select('tr')
    for row in rows:
        num = row.select_one('td:nth-child(1)').text.strip()
        title = row.select_one('td:nth-child(2)').text.strip()
        author = row.select_one('td:nth-child(4)').text.strip()
        date = row.select_one('td:nth-child(5)').text.strip()
        url = 'https://www.mois.go.kr' + row.select_one('a').get('href')
        datas.append( [num, title, author, date, url] )

    if int(page_num) == page:
        break
# Out:
# 1527
# 1528

# %%
page_num
# Out:
# '전체\xa0:\xa015279건\xa0\xa01528/1528'

# %%
page_num.split('/')[-1]
# Out:
# '1528'

# %%
page = 448
page_num = page // 5
if page % 5 != 0:
    page_num += 1
print(page_num)
# Out:
# 90

# %%
url = 'https://www.imdb.com/chart/top/?ref_=nv_mv_250'

headers = {
     'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
     'Referer' : 'https://www.imdb.com/',
     'Accept-Language' : 'en'
}
response = requests.get(url, headers = headers)
print(response)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup.select('ul.ipc-metadata-list > li h3.ipc-title__text')
# Out:
# [<h3 class="ipc-title__text">1. The Shawshank Redemption</h3>,
#  <h3 class="ipc-title__text">2. The Godfather</h3>,
#  <h3 class="ipc-title__text">3. The Dark Knight</h3>,
#  <h3 class="ipc-title__text">4. The Godfather Part II</h3>,
#  <h3 class="ipc-title__text">5. 12 Angry Men</h3>,
#  <h3 class="ipc-title__text">6. Schindler's List</h3>,
#  <h3 class="ipc-title__text">7. The Lord of the Rings: The Return of the King</h3>,
#  <h3 class="ipc-title__text">8. Pulp Fiction</h3>,
#  <h3 class="ipc-title__text">9. The Lord of the Rings: The Fellowship of the Ring</h3>,
#  <h3 class="ipc-title__text">10. The Good, the Bad and the Ugly</h3>,
#  <h3 class="ipc-title__text">11. Forrest Gump</h3>,
#  <h3 class="ipc-title__text">12. Fight Club</h3>,
#  <h3 class="ipc-title__text">13. The Lord of the Rings: The Two Towers</h3>,
#  <h3 class="ipc-title__text">14. Inception</h3>,
#  <h3 class="ipc-title__text">15. Star Wars: Episode V - The Empire Strikes Back</h3>,
#  <h3 class="ipc-title__text">16. The Matrix</h3>,
#  <h3 class="ipc-title__text">17. Goodfellas</h3>,
#  <h3 class="ipc-title__text">18. One Flew Over the Cuckoo's Nest</h3>,
#  <h3 class="ipc-title__text">19. Se7en</h3>,
#  <h3 class="ipc-title__text">20. It's a Wonderful Life</h3>,
#  <h3 class="ipc-title__text">21. Interstellar</h3>,
#  <h3 class="ipc-title__text">22. Seven Samurai</h3>,
#  <h3 class="ipc-title__text">23. The Silence of the Lambs</h3>,
#  <h3 class="ipc-title__text">24. Saving Private Ryan</h3>,
#  <h3 class="ipc-title__text">25. City of God</h3>,
#  <h3 class="ipc-title__text">26. Life Is Beautiful</h3>,
#  <h3 class="ipc-title__text">27. The Green Mile</h3>,
#  <h3 class="ipc-title__text">28. Star Wars: Episode IV - A New Hope</h3>,
#  <h3 class="ipc-title__text">29. Terminator 2: Judgment Day</h3>,
#  <h3 class="ipc-title__text">30. Spider-Man: Across the Spider-Verse</h3>,
#  <h3 class="ipc-title__text">31. Back to the Future</h3>,
#  <h3 class="ipc-title__text">32. Spirited Away</h3>,
#  <h3 class="ipc-title__text">33. The Pianist</h3>,
#  <h3 class="ipc-title__text">34. Parasite</h3>,
#  <h3 class="ipc-title__text">35. Psycho</h3>,
#  <h3 class="ipc-title__text">36. Gladiator</h3>,
#  <h3 class="ipc-title__text">37. The Lion King</h3>,
#  <h3 class="ipc-title__text">38. Léon: The Professional</h3>,
#  <h3 class="ipc-title__text">39. The Departed</h3>,
#  <h3 class="ipc-title__text">40. American History X</h3>,
#  <h3 class="ipc-title__text">41. Whiplash</h3>,
#  <h3 class="ipc-title__text">42. The Prestige</h3>,
#  <h3 class="ipc-title__text">43. Grave of the Fireflies</h3>,
#  <h3 class="ipc-title__text">44. Harakiri</h3>,
#  <h3 class="ipc-title__text">45. The Usual Suspects</h3>,
#  <h3 class="ipc-title__text">46. Casablanca</h3>,
#  <h3 class="ipc-title__text">47. The Intouchables</h3>,
#  <h3 class="ipc-title__text">48. Modern Times</h3>,
#  <h3 class="ipc-title__text">49. Cinema Paradiso</h3>,
#  <h3 class="ipc-title__text">50. Rear Window</h3>,
#  <h3 class="ipc-title__text">51. Once Upon a Time in the West</h3>,
#  <h3 class="ipc-title__text">52. Alien</h3>,
#  <h3 class="ipc-title__text">53. City Lights</h3>,
#  <h3 class="ipc-title__text">54. Apocalypse Now</h3>,
#  <h3 class="ipc-title__text">55. Django Unchained</h3>,
#  <h3 class="ipc-title__text">56. Memento</h3>,
#  <h3 class="ipc-title__text">57. WALL·E</h3>,
#  <h3 class="ipc-title__text">58. Raiders of the Lost Ark</h3>,
#  <h3 class="ipc-title__text">59. 12th Fail</h3>,
#  <h3 class="ipc-title__text">60. The Lives of Others</h3>,
#  <h3 class="ipc-title__text">61. Sunset Blvd.</h3>,
#  <h3 class="ipc-title__text">62. Paths of Glory</h3>,
#  <h3 class="ipc-title__text">63. Avengers: Infinity War</h3>,
#  <h3 class="ipc-title__text">64. Spider-Man: Into the Spider-Verse</h3>,
#  <h3 class="ipc-title__text">65. The Shining</h3>,
#  <h3 class="ipc-title__text">66. Witness for the Prosecution</h3>,
#  <h3 class="ipc-title__text">67. The Great Dictator</h3>,
#  <h3 class="ipc-title__text">68. Aliens</h3>,
#  <h3 class="ipc-title__text">69. Inglourious Basterds</h3>,
#  <h3 class="ipc-title__text">70. The Dark Knight Rises</h3>,
#  <h3 class="ipc-title__text">71. American Beauty</h3>,
#  <h3 class="ipc-title__text">72. Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb</h3>,
#  <h3 class="ipc-title__text">73. Oppenheimer</h3>,
#  <h3 class="ipc-title__text">74. Oldboy</h3>,
#  <h3 class="ipc-title__text">75. Coco</h3>,
#  <h3 class="ipc-title__text">76. Amadeus</h3>,
#  <h3 class="ipc-title__text">77. Toy Story</h3>,
#  <h3 class="ipc-title__text">78. Das Boot</h3>,
#  <h3 class="ipc-title__text">79. Braveheart</h3>,
#  <h3 class="ipc-title__text">80. Avengers: Endgame</h3>,
#  <h3 class="ipc-title__text">81. Joker</h3>,
#  <h3 class="ipc-title__text">82. Princess Mononoke</h3>,
#  <h3 class="ipc-title__text">83. Good Will Hunting</h3>,
#  <h3 class="ipc-title__text">84. Your Name.</h3>,
#  <h3 class="ipc-title__text">85. Once Upon a Time in America</h3>,
#  <h3 class="ipc-title__text">86. 3 Idiots</h3>,
#  <h3 class="ipc-title__text">87. High and Low</h3>,
#  <h3 class="ipc-title__text">88. Singin' in the Rain</h3>,
#  <h3 class="ipc-title__text">89. Capernaum</h3>,
#  <h3 class="ipc-title__text">90. Requiem for a Dream</h3>,
#  <h3 class="ipc-title__text">91. Come and See</h3>,
#  <h3 class="ipc-title__text">92. Toy Story 3</h3>,
#  <h3 class="ipc-title__text">93. Star Wars: Episode VI - Return of the Jedi</h3>,
#  <h3 class="ipc-title__text">94. Eternal Sunshine of the Spotless Mind</h3>,
#  <h3 class="ipc-title__text">95. The Hunt</h3>,
#  <h3 class="ipc-title__text">96. 2001: A Space Odyssey</h3>,
#  <h3 class="ipc-title__text">97. Reservoir Dogs</h3>,
#  <h3 class="ipc-title__text">98. Ikiru</h3>,
#  <h3 class="ipc-title__text">99. Lawrence of Arabia</h3>,
#  <h3 class="ipc-title__text">100. The Apartment</h3>,
#  <h3 class="ipc-title__text">101. Citizen Kane</h3>,
#  <h3 class="ipc-title__text">102. North by Northwest</h3>,
#  <h3 class="ipc-title__text">103. M</h3>,
#  <h3 class="ipc-title__text">104. Vertigo</h3>,
#  <h3 class="ipc-title__text">105. Double Indemnity</h3>,
#  <h3 class="ipc-title__text">106. Scarface</h3>,
#  <h3 class="ipc-title__text">107. Amélie</h3>,
#  <h3 class="ipc-title__text">108. Full Metal Jacket</h3>,
#  <h3 class="ipc-title__text">109. Incendies</h3>,
#  <h3 class="ipc-title__text">110. A Clockwork Orange</h3>,
#  <h3 class="ipc-title__text">111. Heat</h3>,
#  <h3 class="ipc-title__text">112. Up</h3>,
#  <h3 class="ipc-title__text">113. To Kill a Mockingbird</h3>,
#  <h3 class="ipc-title__text">114. The Sting</h3>,
#  <h3 class="ipc-title__text">115. A Separation</h3>,
#  <h3 class="ipc-title__text">116. Hamilton</h3>,
#  <h3 class="ipc-title__text">117. Indiana Jones and the Last Crusade</h3>,
#  <h3 class="ipc-title__text">118. Die Hard</h3>,
#  <h3 class="ipc-title__text">119. Metropolis</h3>,
#  <h3 class="ipc-title__text">120. Like Stars on Earth</h3>,
#  <h3 class="ipc-title__text">121. Snatch</h3>,
#  <h3 class="ipc-title__text">122. Bicycle Thieves</h3>,
#  <h3 class="ipc-title__text">123. L.A. Confidential</h3>,
#  <h3 class="ipc-title__text">124. 1917</h3>,
#  <h3 class="ipc-title__text">125. Taxi Driver</h3>,
#  <h3 class="ipc-title__text">126. Downfall</h3>,
#  <h3 class="ipc-title__text">127. Dangal</h3>,
#  <h3 class="ipc-title__text">128. For a Few Dollars More</h3>,
#  <h3 class="ipc-title__text">129. Batman Begins</h3>,
#  <h3 class="ipc-title__text">130. Some Like It Hot</h3>,
#  <h3 class="ipc-title__text">131. The Wolf of Wall Street</h3>,
#  <h3 class="ipc-title__text">132. The Kid</h3>,
#  <h3 class="ipc-title__text">133. Top Gun: Maverick</h3>,
#  <h3 class="ipc-title__text">134. Green Book</h3>,
#  <h3 class="ipc-title__text">135. The Father</h3>,
#  <h3 class="ipc-title__text">136. All About Eve</h3>,
#  <h3 class="ipc-title__text">137. Judgment at Nuremberg</h3>,
#  <h3 class="ipc-title__text">138. The Truman Show</h3>,
#  <h3 class="ipc-title__text">139. There Will Be Blood</h3>,
#  <h3 class="ipc-title__text">140. Shutter Island</h3>,
#  <h3 class="ipc-title__text">141. Casino</h3>,
#  <h3 class="ipc-title__text">142. Ran</h3>,
#  <h3 class="ipc-title__text">143. Jurassic Park</h3>,
#  <h3 class="ipc-title__text">144. Pan's Labyrinth</h3>,
#  <h3 class="ipc-title__text">145. The Sixth Sense</h3>,
#  <h3 class="ipc-title__text">146. Unforgiven</h3>,
#  <h3 class="ipc-title__text">147. Poor Things</h3>,
#  <h3 class="ipc-title__text">148. A Beautiful Mind</h3>,
#  <h3 class="ipc-title__text">149. No Country for Old Men</h3>,
#  <h3 class="ipc-title__text">150. The Treasure of the Sierra Madre</h3>,
#  <h3 class="ipc-title__text">151. Yojimbo</h3>,
#  <h3 class="ipc-title__text">152. The Thing</h3>,
#  <h3 class="ipc-title__text">153. Kill Bill: Vol. 1</h3>,
#  <h3 class="ipc-title__text">154. Monty Python and the Holy Grail</h3>,
#  <h3 class="ipc-title__text">155. The Great Escape</h3>,
#  <h3 class="ipc-title__text">156. Finding Nemo</h3>,
#  <h3 class="ipc-title__text">157. Rashomon</h3>,
#  <h3 class="ipc-title__text">158. The Elephant Man</h3>,
#  <h3 class="ipc-title__text">159. Chinatown</h3>,
#  <h3 class="ipc-title__text">160. Howl's Moving Castle</h3>,
#  <h3 class="ipc-title__text">161. Prisoners</h3>,
#  <h3 class="ipc-title__text">162. Dial M for Murder</h3>,
#  <h3 class="ipc-title__text">163. Gone with the Wind</h3>,
#  <h3 class="ipc-title__text">164. V for Vendetta</h3>,
#  <h3 class="ipc-title__text">165. Lock, Stock and Two Smoking Barrels</h3>,
#  <h3 class="ipc-title__text">166. The Secret in Their Eyes</h3>,
#  <h3 class="ipc-title__text">167. Raging Bull</h3>,
#  <h3 class="ipc-title__text">168. Inside Out</h3>,
#  <h3 class="ipc-title__text">169. Three Billboards Outside Ebbing, Missouri</h3>,
#  <h3 class="ipc-title__text">170. Spider-Man: No Way Home</h3>,
#  <h3 class="ipc-title__text">171. Trainspotting</h3>,
#  <h3 class="ipc-title__text">172. The Bridge on the River Kwai</h3>,
#  <h3 class="ipc-title__text">173. Godzilla Minus One</h3>,
#  <h3 class="ipc-title__text">174. Fargo</h3>,
#  <h3 class="ipc-title__text">175. Warrior</h3>,
#  <h3 class="ipc-title__text">176. Klaus</h3>,
#  <h3 class="ipc-title__text">177. Catch Me If You Can</h3>,
#  <h3 class="ipc-title__text">178. Gran Torino</h3>,
#  <h3 class="ipc-title__text">179. My Neighbor Totoro</h3>,
#  <h3 class="ipc-title__text">180. Million Dollar Baby</h3>,
#  <h3 class="ipc-title__text">181. Harry Potter and the Deathly Hallows: Part 2</h3>,
#  <h3 class="ipc-title__text">182. Children of Heaven</h3>,
#  <h3 class="ipc-title__text">183. Blade Runner</h3>,
#  <h3 class="ipc-title__text">184. 12 Years a Slave</h3>,
#  <h3 class="ipc-title__text">185. Before Sunrise</h3>,
#  <h3 class="ipc-title__text">186. The Grand Budapest Hotel</h3>,
#  <h3 class="ipc-title__text">187. Ben-Hur</h3>,
#  <h3 class="ipc-title__text">188. Barry Lyndon</h3>,
#  <h3 class="ipc-title__text">189. Gone Girl</h3>,
#  <h3 class="ipc-title__text">190. The Gold Rush</h3>,
#  <h3 class="ipc-title__text">191. Hacksaw Ridge</h3>,
#  <h3 class="ipc-title__text">192. In the Name of the Father</h3>,
#  <h3 class="ipc-title__text">193. Memories of Murder</h3>,
#  <h3 class="ipc-title__text">194. On the Waterfront</h3>,
#  <h3 class="ipc-title__text">195. The General</h3>,
#  <h3 class="ipc-title__text">196. The Deer Hunter</h3>,
#  <h3 class="ipc-title__text">197. Dead Poets Society</h3>,
#  <h3 class="ipc-title__text">198. Wild Tales</h3>,
#  <h3 class="ipc-title__text">199. Mad Max: Fury Road</h3>,
#  <h3 class="ipc-title__text">200. Wild Strawberries</h3>,
#  <h3 class="ipc-title__text">201. The Third Man</h3>,
#  <h3 class="ipc-title__text">202. Sherlock Jr.</h3>,
#  <h3 class="ipc-title__text">203. The Wages of Fear</h3>,
#  <h3 class="ipc-title__text">204. Monsters, Inc.</h3>,
#  <h3 class="ipc-title__text">205. Mr. Smith Goes to Washington</h3>,
#  <h3 class="ipc-title__text">206. Jaws</h3>,
#  <h3 class="ipc-title__text">207. How to Train Your Dragon</h3>,
#  <h3 class="ipc-title__text">208. Mary and Max</h3>,
#  <h3 class="ipc-title__text">209. Ford v Ferrari</h3>,
#  <h3 class="ipc-title__text">210. Ratatouille</h3>,
#  <h3 class="ipc-title__text">211. The Seventh Seal</h3>,
#  <h3 class="ipc-title__text">212. Room</h3>,
#  <h3 class="ipc-title__text">213. The Big Lebowski</h3>,
#  <h3 class="ipc-title__text">214. Tokyo Story</h3>,
#  <h3 class="ipc-title__text">215. Rocky</h3>,
#  <h3 class="ipc-title__text">216. Hotel Rwanda</h3>,
#  <h3 class="ipc-title__text">217. Logan</h3>,
#  <h3 class="ipc-title__text">218. Spotlight</h3>,
#  <h3 class="ipc-title__text">219. Platoon</h3>,
#  <h3 class="ipc-title__text">220. The Passion of Joan of Arc</h3>,
#  <h3 class="ipc-title__text">221. The Terminator</h3>,
#  <h3 class="ipc-title__text">222. Jai Bhim</h3>,
#  <h3 class="ipc-title__text">223. Before Sunset</h3>,
#  <h3 class="ipc-title__text">224. Rush</h3>,
#  <h3 class="ipc-title__text">225. The Best Years of Our Lives</h3>,
#  <h3 class="ipc-title__text">226. Network</h3>,
#  <h3 class="ipc-title__text">227. La haine</h3>,
#  <h3 class="ipc-title__text">228. The Exorcist</h3>,
#  <h3 class="ipc-title__text">229. Stand by Me</h3>,
#  <h3 class="ipc-title__text">230. Pirates of the Caribbean: The Curse of the Black Pearl</h3>,
#  <h3 class="ipc-title__text">231. The Wizard of Oz</h3>,
#  <h3 class="ipc-title__text">232. The Incredibles</h3>,
#  <h3 class="ipc-title__text">233. Into the Wild</h3>,
#  <h3 class="ipc-title__text">234. Hachi: A Dog's Tale</h3>,
#  <h3 class="ipc-title__text">235. The Handmaiden</h3>,
#  <h3 class="ipc-title__text">236. To Be or Not to Be</h3>,
#  <h3 class="ipc-title__text">237. My Father and My Son</h3>,
#  <h3 class="ipc-title__text">238. The Battle of Algiers</h3>,
#  <h3 class="ipc-title__text">239. The Grapes of Wrath</h3>,
#  <h3 class="ipc-title__text">240. Groundhog Day</h3>,
#  <h3 class="ipc-title__text">241. The Sound of Music</h3>,
#  <h3 class="ipc-title__text">242. Amores Perros</h3>,
#  <h3 class="ipc-title__text">243. Rebecca</h3>,
#  <h3 class="ipc-title__text">244. Cool Hand Luke</h3>,
#  <h3 class="ipc-title__text">245. The Iron Giant</h3>,
#  <h3 class="ipc-title__text">246. The Help</h3>,
#  <h3 class="ipc-title__text">247. It Happened One Night</h3>,
#  <h3 class="ipc-title__text">248. The 400 Blows</h3>,
#  <h3 class="ipc-title__text">249. Pather Panchali</h3>,
#  <h3 class="ipc-title__text">250. Aladdin</h3>]

# %%
page = 1
size = 5
while True:
    url = 'https://dapi.kakao.com/v2/local/search/category.json'
    params = { 'category_group_code' : 'FD6', 
                'x' : '127.325356593945',
                'y' : '36.4910924250367',
                'radius' : '1000',
                'size' : size,
                'page' : page
             }
    headers = { 'Authorization' : 'KakaoAK ' + 'd44eaac9a1ae4db5ec4a3b895553fb84'}
    response = requests.get(url, params = params, headers = headers)
    
    for item in response.json()['documents']:
        print(item['place_name'])
    
    if not response.json()['meta']['is_end']:
        page += 1
    else:
        break
# Out:
# 서리서리멸치국수 집현점
# 집현각
# 길림성 세종집현점
# 롯데리아 세종테크밸리점
# 한솥도시락 세종집현점
# BBQ 세종집현점
# 파리바게뜨 세종집현테크노점
# 역전우동0410 세종집현점
# BHC치킨 세종집현점
# 배스킨라빈스 세종집현점
# 강남 김밥
# 온식당
# 본죽&비빔밥cafe 세종집현점
# 세종한식당
# 고봉민김밥인
# 미태리 세종집현점
# 큰맘할매순대국 세종집현점
# 허바허바 세종집현점
# 비전세미콘 구내식당
# 킹콩부대찌개 세종대명밸리온점
# 김밥천국 집현점
# 디디디엔피자

# %%
response.json()['documents'][0]['place_name']
# Out:
# 'GS25 세종엘디스점'

# %%
url = 'https://www.gmarket.co.kr/n/best'

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
images = soup.select('img.image__lazy')
best_items = []
for image in images:
    code = image.get('src').split('/')[3]
    img_url = 'https:' + image.get('src')
    title = image.get('alt')
    best_items.append([code, title, img_url])

# %%
best_items[:3]
# Out:
# [['3020358073',
#   '진미채볶음 500g대용량 여수김치명가제조 촉촉하고 쫄깃한 오징어풍미와 달큰양념',
#   'https://gdimg.gmarket.co.kr/3020358073/still/300?ver=1687402881'],
#  ['2242733085',
#   '[비비고][비비고] (CJ제일제당) 맛밤 50g 40봉 (1박스)',
#   'https://gdimg.gmarket.co.kr/2242733085/still/300?ver=1705303116'],
#  ['2420314425',
#   '[마녀바스켓](반찬종합세트) 무말랭이1kg+깻잎무침1kg+간장고추1kg/쿠폰가 13100원',
#   'https://gdimg.gmarket.co.kr/2420314425/still/300?ver=1701654863']]

# %%
len(best_items)
# Out:
# 200

# %%
for num, item in enumerate(best_items):
    response = requests.get(item[2])

    with open(f'images/{num}.jpeg', 'wb') as f:
        f.write(response.content)

# %%
from urllib.request import urlopen, urlretrieve

# %%
for num, item in enumerate(best_items):
    urlretrieve(item[2], f'images2/{num}.jpeg')

# %%
urlretrieve('https://naver.com', 'naver.html')
# Out:
# ('naver.html', <http.client.HTTPMessage at 0x208bf17ff90>)

# %%
import pymysql

conn = pymysql.connect(user = 'maria', 
                        password = '1234',
                        host = 'localhost',
                        port = 3306,
                        database = 'python_db')

# %%
response = requests.get(best_items[0][2])
response.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xed%XPhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x07\x1c\x02\x00\x00\x02\x00\x00\x008BIM\x04%\x00\x00\x00\x00\x00\x10\xe8\xf1\\\xf3/\xc1\x18\xa1\xa2{g\xad\xc5d\xd5\xba8BIM\x04:\x00\x00\x00\x00\x00\xe3\x00\x00\x00\x10\x00\x00\x00\x01\x00\x00\x00\x00\x00\x0bprintOutput\x00\x00\x00\x05\x00\x00\x00\x00PstSbool\x01\x00\x00\x00\x00Inteenum\x00\x00\x00\x00Inte\x00\x00\x00\x00Img \x00\x00\x00\x0fprintSixteenBitbool\x00\x00\x00\x00\x0bprinterNameTEXT\x00\x00\x00\x01\x00\x00\x00\x00\x00\x0fprintProofSetupObjc\x00\x00\x00\x0b\xc8\x00\xd5t\xc0\xc1\xb3\xc4\x00 \xc7x\xc1\xc4\x00 \xc1$\xc8\x15\x00\x00\x00\x00\x00\nproofSetup\x00\x00\x00\x01\x00\x00\x00\x00Bltnenum\x00\x00\x00\x0cbuiltinProof\x00\x00\x00\tproofCMYK\x008BIM\x04;\x00\x00\x00\x00\x02-\x00\x00\x00\x10\x00\x00\x00\x01\x00\x00\x00\x00\x00\x12printOutputOptions\x00\x00\x00\x17\x00\x00\x00\x00Cptnbool\x00\x00\x00\x00\x00Clbrbool\x00\x00\x00\x00\x00RgsMbool\x00\x00\x00\x00\x00CrnCbool\x00\x00\x00\x00\x00CntCbool\x00\x00\x00\x00\x00Lblsbool\x00\x00\x00\x00\x00Ngtvbool\x00\x00\x00\x00\x00EmlDbool\x00\x00\x00\x00\x00Intrbool\x00\x00\x00\x00\x00BckgObjc\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00RGBC\x00\x00\x00\x03\x00\x00\x00\x00Rd  doub@o\xe0\x00\x00\x00\x00\x00\x00\x00\x00\x00Grn doub@o\xe0\x00\x00\x00\x00\x00\x00\x00\x00\x00Bl  doub@o\xe0\x00\x00\x00\x00\x00\x00\x00\x00\x00BrdTUntF#Rlt\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00Bld UntF#Rlt\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00RsltUntF#Pxl@R\x00\x00\x00\x00\x00\x00\x00\x00\x00\nvectorDatabool\x01\x00\x00\x00\x00PgPsenum\x00\x00\x00\x00PgPs\x00\x00\x00\x00PgPC\x00\x00\x00\x00LeftUntF#Rlt\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00Top UntF#Rlt\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00Scl UntF#Prc@Y\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10cropWhenPrintingbool\x00\x00\x00\x00\x0ecropRectBottomlong\x00\x00\x00\x00\x00\x00\x00\x0ccropRectLeftlong\x00\x00\x00\x00\x00\x00\x00\rcropRectRightlong\x00\x00\x00\x00\x00\x00\x00\x0bcropRectToplong\x00\x00\x00\x00\x008BIM\x03\xed\x00\x00\x00\x00\x00\x10\x00H\x00\x00\x00\x01\x00\x02\x00H\x00\x00\x00\x01\x00\x028BIM\x04&\x00\x00\x00\x00\x00\x0e\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00?\x80\x00\x008BIM\x03\xf2\x00\x00\x00\x00\x00\n\x00\x00\xff\xff\xff\xff\xff\xff\x00\x008BIM\x04\r\x00\x00\x00\x00\x00\x04\x00\x00\x00Z8BIM\x04\x19\x00\x00\x00\x00\x00\x04\x00\x00\x00\x1e8BIM\x03\xf3\x00\x00\x00\x00\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x01\x008BIM\'\x10\x00\x00\x00\x00\x00\n\x00\x01\x00\x00\x00\x00\x00\x00\x00\x028BIM\x03\xf5\x00\x00\x00\x00\x00H\x00/ff\x00\x01\x00lff\x00\x06\x00\x00\x00\x00\x00\x01\x00/ff\x00\x01\x00\xa1\x99\x9a\x00\x06\x00\x00\x00\x00\x00\x01\x002\x00\x00\x00\x01\x00Z\x00\x00\x00\x06\x00\x00\x00\x00\x00\x01\x005\x00\x00\x00\x01\x00-\x00\x00\x00\x06\x00\x00\x00\x00\x00\x018BIM\x03\xf8\x00\x00\x00\x00\x00p8BIM\x04\x08\x00\x00\x00\x00\x00\x10\x00\x00\x00\x01\x00\x00\x02@\x00\x00\x02@\x00\x00\x00\x008BIM\x04\x1e\x00\x00\x00\x00\x00\x04\x00\x00\x00\x008BIM\x04\x1a\x00\x00\x00\x00\x03K\x00\x00\x00\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\xe8\x00\x00\x03\xe8\x00\x00\x00\x0b\xbb4\xb9\xd0\xb7\xad\xc7t\x00_\x00t\x00h\x00u\x00m\x00b\x002\ ...

# %%
from PIL import Image
import io

img = Image.open(io.BytesIO(response.content))
img.show()

# %%
cursor = conn.cursor()
sql = f'''insert into gmarket values (%s)'''
cursor.execute(sql, [response.content])
conn.commit()
conn.close()
# Out:
# <bound method Connection.close of <pymysql.connections.Connection object at 0x00000208BF04D590>>

# %%
url = 'https://item.gmarket.co.kr/Review/Premium'

for item in best_items:
    params = {'goodsCode' : item[0], 'pageNo' : 1, 'sort': 0, 'totalPage':9999}
    response = requests.post(url, params = params)
    print(response)
    break
# Out:
# <Response [200]>

# %%
all_revies = []
review = BeautifulSoup(response.content, 'html.parser')
rows = review.select('table > tbody tr')
for row in rows:
    title = row.select_one('td p:nth-child(1)').text.strip()
    content = row.select_one('td p:nth-child(3)').text.strip()
    all_revies.append([title, content])

# %%
all_revies
# Out:
# [['진미채볶음', '맛있어요\n아이들과 잘 먹고있어요'],
#  ['맛있어요', '양념이 찐하고  맛있어요'],
#  ['좋아요', '맛있어요\n근데 생각보다 양이 적어요~'],
#  ['진짜 맛있어요~^^', '진미채 부드럽고 진짜 맛있어요~^^'],
#  ['맛있어요~^^', '진미채 진짜 맛있어요~^^\n집에서 만든것처럼~^^']]

# %%
import pymysql

conn = pymysql.connect(user = 'maria', 
                        password = '1234',
                        host = 'localhost',
                        port = 3306,
                        database = 'python_db')
cursor = conn.cursor()

# %%
sql = '''insert into reviews (title, content) values (%s, %s)'''
cursor.execute(sql, all_revies[0])
conn.commit()

conn.close()
